# %% [markdown]
# # Titanic classification with MOSTLY AI Engine
#
# This notebook trains the tabular generator on the Titanic dataset, generates synthetic data, and computes class probabilities for `survived` conditioned on all other features.

# %%
# If running in a fresh environment, ensure the 'uv' kernel is available.
# You can create a kernel bound to the current uv virtual environment with:
#   uv run python -m ipykernel install --user --name=mostlyai-uv --display-name "Python (mostlyai-uv)"
# Then, in Jupyter, select the kernel "Python (mostlyai-uv)".

from pathlib import Path

import pandas as pd

from mostlyai import engine
from mostlyai.engine.domain import ModelType

ROOT = Path("..").resolve()
DATA_PATH = ROOT / "data" / "titanic_unbalanced.csv"


df = pd.read_csv(DATA_PATH)

features = [c for c in df.columns if c != "survived"]
ws = ROOT / "ws-titanic-unbalanced-classify"

engine.init_logging()

# %%
# Train the generator
engine.split(workspace_dir=ws, tgt_data=df, model_type=ModelType.tabular)
engine.analyze(workspace_dir=ws, value_protection=False)
engine.encode(workspace_dir=ws)
engine.train(workspace_dir=ws, enable_flexible_generation=True)
# Out:
# [2025-10-02 13:56:55,265] INFO   : SPLIT started
# [2025-10-02 13:56:55,267] INFO   : create `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/OriginalData/tgt-data`
# [2025-10-02 13:56:55,268] INFO   : create `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/OriginalData/tgt-meta`
# [2025-10-02 13:56:55,270] INFO   : model_type='TABULAR'
# [2025-10-02 13:56:55,270] INFO   : tgt_encoding_types={'survived': 'TABULAR_NUMERIC_AUTO', 'pclass': 'TABULAR_NUMERIC_AUTO', 'sex': 'TABULAR_CATEGORICAL', 'age': 'TABULAR_NUMERIC_AUTO', 'sibsp': 'TABULAR_NUMERIC_AUTO', 'parch': 'TABULAR_NUMERIC_AUTO', 'fare': 'TABULAR_NUMERIC_AUTO', 'embarked': 'TABULAR_CATEGORICAL'}
# [2025-10-02 13:56:55,281] INFO   : SPLIT finished in 0.01s
# [2025-10-02 13:56:55,281] INFO   : ANALYZE started
# [2025-10-02 13:56:55,283] INFO   : create `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/ModelStore/tgt-stats`
# [2025-10-02 13:56:55,284] INFO   : analyzing 2 partitions in parallel
# [2025-10-02 13:56:57,803] INFO   : analyzed target partition 000000-trn (400, 8)
# [2025-10-02 13:56:59,331] INFO   : analyzed target partition 000000-val (100, 8)
# [2025-10-02 13:56:59,332] INFO   : combine partition statistics
# [2025-10-02 13:56:59,336] INFO   : value_protection = False
# [2025-10-02 13:56:59,337] INFO   : analyzed column `survived`: TABULAR_NUMERIC_DISCRETE {'cat': 3}
# [2025-10-02 13:56:59,338] INFO   : analyzed column `pclass`: TABULAR_NUMERIC_DISCRETE {'cat': 4}
# [2025-10-02 13:56:59,339] INFO   : analyzed column `sex`: TABULAR_CATEGORICAL {'cat': 3}
# [2025-10-02 13:56:59,341] INFO   : analyzed column `age`: TABULAR_NUMERIC_DISCRETE {'cat': 65}
# [2025-10-02 13:56:59,342] INFO   : analyzed column `sibsp`: TABULAR_NUMERIC_DISCRETE {'cat': 8}
# [2025-10-02 13:56:59,343] INFO   : analyzed column `parch`: TABULAR_NUMERIC_DISCRETE {'cat': 9}
# [2025-10-02 13:56:59,345] INFO   : analyzed column `fare`: TABULAR_NUMERIC_DISCRETE {'cat': 73}
# [2025-10-02 13:56:59,346] INFO   : analyzed column `embarked`: TABULAR_CATEGORICAL {'cat': 4}
# [2025-10-02 13:56:59,346] INFO   : analyzed 500 records: 400 training / 100 validation
# [2025-10-02 13:56:59,347] INFO   : is_sequential: False
# [2025-10-02 13:56:59,348] INFO   : write statistics to `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/ModelStore/tgt-stats/stats.json`
# [2025-10-02 13:56:59,352] INFO   : ANALYZE finished in 4.07s
# [2025-10-02 13:56:59,354] INFO   : ENCODE_TABULAR started
# [2025-10-02 13:56:59,356] INFO   : create `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/OriginalData/encoded-data`
# [2025-10-02 13:56:59,356] INFO   : clean `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/OriginalData/encoded-data`
# [2025-10-02 13:56:59,357] INFO   : clean `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/OriginalData/encoded-data`
# [2025-10-02 13:56:59,387] INFO   : encoded partition part.000000-trn.parquet (400, 8)
# [2025-10-02 13:56:59,405] INFO   : encoded partition part.000000-val.parquet (100, 8)
# [2025-10-02 13:56:59,406] INFO   : ENCODE_TABULAR finished in 0.05s
# [2025-10-02 13:56:59,408] INFO   : TRAIN_TABULAR started
# [2025-10-02 13:56:59,418] INFO   : numpy=2.2.6, pandas=2.2.3
# [2025-10-02 13:56:59,420] INFO   : torch=2.8.0, opacus=1.5.4
# [2025-10-02 13:56:59,420] INFO   : device=device(type='cpu')
# [2025-10-02 13:56:59,421] INFO   : is_sequential=False
# [2025-10-02 13:56:59,422] INFO   : max_training_time=864000.0s
# [2025-10-02 13:56:59,422] INFO   : max_epochs=100.0 -> max_epochs=10 due to small sample size
# [2025-10-02 13:56:59,423] INFO   : model_size=<ModelSize.M: 'M'>
# [2025-10-02 13:56:59,423] INFO   : enable_flexible_generation=True
# [2025-10-02 13:56:59,424] INFO   : with_dp=False
# [2025-10-02 13:56:59,424] INFO   : model_state_strategy=<ModelStateStrategy.reset: 'RESET'>
# [2025-10-02 13:56:59,425] INFO   : max_sequence_window=np.int64(1)
# [2025-10-02 13:56:59,426] INFO   : create training model
# [2025-10-02 13:56:59,429] INFO   : model class: FlatModel
# [2025-10-02 13:56:59,430] INFO   : model weights not found; change strategy from RESET to RESET
# [2025-10-02 13:56:59,430] INFO   : model_state_strategy=<ModelStateStrategy.reset: 'RESET'>
# [2025-10-02 13:56:59,431] INFO   : remove existing checkpoint files
# [2025-10-02 13:56:59,432] INFO   : start training progress from epoch=0.0, steps=0
# [2025-10-02 13:56:59,434] INFO   : no_of_model_params=np.int64(24656)
# [2025-10-02 13:57:00,147] INFO   : trn_cnt=400, val_cnt=100
# [2025-10-02 13:57:00,149] INFO   : len(tgt_sub_columns)=8, len(ctxflt_sub_columns)=0, len(ctxseq_sub_columns)=0
# [2025-10-02 13:57:00,152] INFO   : tgt_cardinalities_deciles=[np.int64(3), np.int64(3), np.int64(3), np.int64(4), np.int64(4), np.int64(4), np.int64(8), np.int64(8), np.int64(9), np.int64(65), np.int64(73)]
# [2025-10-02 13:57:00,153] INFO   : trn_batch_size=8, val_batch_size=8
# [2025-10-02 13:57:00,155] INFO   : trn_steps=50, val_steps=12
# [2025-10-02 13:57:00,157] INFO   : batch_size=8, gradient_accumulation_steps=1, initial_lr=np.float64(0.0005)
# [2025-10-02 13:57:00,169] INFO   : {'epoch': 0.02, 'is_checkpoint': 0, 'steps': 1, 'samples': 8, 'trn_loss': 17.7035, 'val_loss': None, 'total_time': 0.0, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:00,501] INFO   : {'epoch': 1.0, 'is_checkpoint': 1, 'steps': 50, 'samples': 400, 'trn_loss': 16.7765, 'val_loss': 16.0137, 'total_time': 0.3, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:00,822] INFO   : {'epoch': 2.0, 'is_checkpoint': 1, 'steps': 100, 'samples': 800, 'trn_loss': 15.3129, 'val_loss': 14.6608, 'total_time': 0.7, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:01,141] INFO   : {'epoch': 3.0, 'is_checkpoint': 1, 'steps': 150, 'samples': 1200, 'trn_loss': 13.865, 'val_loss': 13.1428, 'total_time': 1.0, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:01,474] INFO   : {'epoch': 4.0, 'is_checkpoint': 1, 'steps': 200, 'samples': 1600, 'trn_loss': 12.5897, 'val_loss': 12.5954, 'total_time': 1.3, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:01,849] INFO   : {'epoch': 5.0, 'is_checkpoint': 1, 'steps': 250, 'samples': 2000, 'trn_loss': 12.1327, 'val_loss': 12.0971, 'total_time': 1.7, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:02,203] INFO   : {'epoch': 6.0, 'is_checkpoint': 1, 'steps': 300, 'samples': 2400, 'trn_loss': 11.7146, 'val_loss': 11.695, 'total_time': 2.0, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:02,540] INFO   : {'epoch': 7.0, 'is_checkpoint': 1, 'steps': 350, 'samples': 2800, 'trn_loss': 11.5082, 'val_loss': 11.5348, 'total_time': 2.4, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:02,865] INFO   : {'epoch': 8.0, 'is_checkpoint': 1, 'steps': 400, 'samples': 3200, 'trn_loss': 11.2801, 'val_loss': 11.3427, 'total_time': 2.7, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:03,191] INFO   : {'epoch': 9.0, 'is_checkpoint': 1, 'steps': 450, 'samples': 3600, 'trn_loss': 11.3629, 'val_loss': 11.1632, 'total_time': 3.0, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:03,520] INFO   : {'epoch': 10.0, 'is_checkpoint': 1, 'steps': 500, 'samples': 4000, 'trn_loss': 11.0095, 'val_loss': 11.1424, 'total_time': 3.4, 'learn_rate': 0.0005, 'dp_eps': None, 'dp_delta': None}
# [2025-10-02 13:57:03,531] INFO   : TRAIN_TABULAR finished in 4.12s

# %%
# Generate synthetic data (optional)
engine.generate(workspace_dir=ws, sample_size=len(df))
# Out:
# [2025-10-02 13:57:07,762] INFO   : GENERATE_TABULAR started
# [2025-10-02 13:57:07,763] INFO   : create `/home/ivona/git/mostlyai-engine/ws-titanic-unbalanced-classify/SyntheticData`
# [2025-10-02 13:57:07,765] INFO   : is_sequential=False
# [2025-10-02 13:57:07,765] INFO   : has_context=False
# [2025-10-02 13:57:07,766] INFO   : enable_flexible_generation=True
# [2025-10-02 13:57:07,767] INFO   : len(tgt_sub_columns)=8
# [2025-10-02 13:57:07,768] INFO   : len(ctx_sub_columns)=0
# [2025-10-02 13:57:07,768] INFO   : device=device(type='cpu')
# [2025-10-02 13:57:07,769] INFO   : tgt_primary_key=None, tgt_context_key=None, ctx_primary_key=None
# [2025-10-02 13:57:07,770] INFO   : imputation: None
# [2025-10-02 13:57:07,770] INFO   : rebalancing: None
# [2025-10-02 13:57:07,771] INFO   : fairness: None
# [2025-10-02 13:57:07,771] INFO   : seed_data: None
# [2025-10-02 13:57:07,772] INFO   : gen_column_order=['tgt:t0/c0', 'tgt:t1/c1', 'tgt:t2/c2', 'tgt:t3/c3', 'tgt:t4/c4', 'tgt:t5/c5', 'tgt:t6/c6', 'tgt:t7/c7']
# [2025-10-02 13:57:07,772] INFO   : rare_category_replacement_method=<RareCategoryReplacementMethod.constant: 'CONSTANT'>
# [2025-10-02 13:57:07,773] INFO   : imputation: []
# [2025-10-02 13:57:07,773] INFO   : rebalance_column: None
# [2025-10-02 13:57:07,773] INFO   : rebalance_probabilities: {}
# [2025-10-02 13:57:07,774] INFO   : sampling_temperature=1.0, sampling_top_p=1.0
# [2025-10-02 13:57:07,778] INFO   : batch_size heuristic: 100,000 (mem_available_gb=12.1GB, sample_kb=0.7KB, scaling_factor=0.1)
# [2025-10-02 13:57:07,779] INFO   : sample_size=500
# [2025-10-02 13:57:07,780] INFO   : list(seed_data.columns)=['__dummy_context_key']
# [2025-10-02 13:57:07,780] INFO   : batch_size=500
# [2025-10-02 13:57:07,780] INFO   : no_of_batches=1
# [2025-10-02 13:57:07,781] INFO   : create generative model
# [2025-10-02 13:57:07,787] INFO   : no_of_model_params=np.int64(24656)
# [2025-10-02 13:57:07,797] INFO   : loaded model weights in 0.01s
# [2025-10-02 13:57:07,800] INFO   : generate 1 batches
# [2025-10-02 13:57:07,803] INFO   : encode context (500, 1)
# [2025-10-02 13:57:07,805] INFO   : encode seed data values (500, 1)
# [2025-10-02 13:57:07,806] INFO   : sample data from model with context (500, 1)
# [2025-10-02 13:57:07,823] INFO   : decode generated data (500, 9)
# [2025-10-02 13:57:07,858] INFO   : post-process generated data (500, 9)
# [2025-10-02 13:57:07,863] INFO   : persisted (500, 8) to `part.000000.000000.parquet` in 0.00s
# [2025-10-02 13:57:07,863] INFO   : GENERATE_TABULAR finished in 0.10s

# %%
# Classify 'survived' using all other columns as features
proba_df = engine.classify(data=df, features=features, target="survived", workspace_dir=ws)
proba_df.head()
# Out:
# [2025-10-02 13:57:10,861] INFO   : loaded model weights in 0.01s
#    pclass     sex   age  sibsp  parch  fare embarked  proba__RARE_   proba_0  \
# 0       3  female  18.0      0      0   8.0        S      0.000330  0.998486
# 1       3    male  28.0      0      0   8.0        S      0.001703  0.996027
# 2       3    male  24.0      1      0  16.0        S      0.002197  0.994770
# 3       3    male  23.0      0      0   9.0        S      0.001203  0.996359
# 4       3    male  18.0      1      0   6.0        S      0.001577  0.994884
#
#     proba_1
# 0  0.001184
# 1  0.002271
# 2  0.003032
# 3  0.002438
# 4  0.003539

# %%
# Classify 'survived' using all other columns as features
proba_df2 = engine.classify(data=df, features=[], target="survived", workspace_dir=ws)
proba_df2.head()
# Out:
# [2025-10-02 14:07:24,324] INFO   : loaded model weights in 0.01s
#    proba__RARE_   proba_0   proba_1
# 0      0.180144  0.653679  0.166178
# 1      0.180144  0.653679  0.166178
# 2      0.180144  0.653679  0.166178
# 3      0.180144  0.653679  0.166178
# 4      0.180144  0.653679  0.166178

# %%
# !uv pip install plotly

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook"

# %%
def compare_probs(df, p1, p2):
    cols_to_plot = ["pro", "proba_1"]

    # Melt the dataframe into long format
    df_melted = proba_df.melt(value_vars=cols_to_plot, var_name="feature", value_name="value")

    # Create overlapping histograms
    fig = px.histogram(
        df_melted,
        x="value",
        color="feature",
        barmode="overlay",  # overlay histograms
        opacity=0.6,  # slight transparency so both show
        marginal="box",  # optional: adds a boxplot on the side
    )

    fig.update_layout(title="Histograms of RARE and minority class", xaxis_title="Value", yaxis_title="Count")

    fig.show()

# %%
# Choose the two columns you want to compare
cols_to_plot = ["proba__RARE_", "proba_1"]

# Melt the dataframe into long format
df_melted = proba_df.melt(value_vars=cols_to_plot, var_name="feature", value_name="value")

# Create overlapping histograms
fig = px.histogram(
    df_melted,
    x="value",
    color="feature",
    barmode="overlay",  # overlay histograms
    opacity=0.6,  # slight transparency so both show
    marginal="box",  # optional: adds a boxplot on the side
)

fig.update_layout(title="Histograms of RARE and minority class", xaxis_title="Value", yaxis_title="Count")

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="9cba830e-6645-4aaf-9788-6416e2c38268" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9cba830e-6645-4aaf-9788-6416e2c38268")) {                    Plotly.newPlot(                        "9cba830e-6645-4aaf-9788-6416e2c38268",                        [{"bingroup":"x","hovertemplate":"feature=proba__RARE_\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"proba__RARE_","marker":{"color":"#636efa","opacity":0.6,"pattern":{"shape":""}},"name":"proba__RARE_","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"1UGtOTot3zpQABA7qJ6dOkTBzjoh68M7L9ogOh20aDriQrA7yqEoOrHvDzqzFqU7OUYNOxNtCDshY7w5WEeJOS1HPTuenwY8sotaOz0jpTn3+0E7IPOROdOjqjrSChY7ol7xOqoQuztJ0Ik5OHx3O6M57Tkwl9E6ktF\u002fOqHKazoMH8M6Dau0O93VKDpr2AM66c3KOpT4djquSk46LksxPVahcDsW0bk6UiNOOaP5gTrm9xc7\u002frLLORNHtDoPRX46Oi3fOtY2FDpqWQk7cOO6OY29wDqOgCk6XkBFOZIWVTwHdf86nQErO3fXUjse9Jk6JdkDOvLuvzqhIJA65bCTOhmWFjx2zdc7\u002fRoXO6mqdjqgGSQ6oBkkOkPvDjrz\u002fxQ8kN0LOg3LLTsQcx87qwOdPN6oxjv9Q986zwT9OtOjqjolmxs77OCrOTDlmToAh6E6R3zMPAsilTvoDcw8DD4QO\u002fZjKzvs4Ks58nHoOY6AKTrHsuM5CNraO2Mq0jrs4Ks5aXuJPJp4ATvNgIM7ixIIPZDdCzq2em86TH0CPKtrSzqCinw7GJ92OqAZJDrjN8Y8OIeDOklX4jmQ3Qs68u6\u002fOpsQCTv0FTw6EdUJPHDjujm3T6g7hZIjOrBUMjwW0bk6DMjxOvNz4zrw\u002f0U67r+jOun9STq2em865TWYOkfQqTpYWUY60DjqOo6AKTq9ceU67OCrOXiqfDmgGSQ6icBTPJ0BKzvRUgY7sIRbO+1SKzsAgRk6alkJO3Djujk21R86tWpqO6HKazrs4Ks57OCrOaQXOTvgp4w7uA0rPBr2NTtqWQk7gjmdOvAnmjkw5Zk6X5q3Ot\u002foGz1eQEU5oE\u002f2O9Y2FDpVA5U7mGveOr\u002fuHj37O+85cOO6OYWSIzrltws7zIPxOsoW\u002fTrs4Ks5yf\u002fNOs4YoTo\u002fxdk67OCrOezgqznViXA7MOWZOl5b0zvxz7s5hu4pO5IfZDveKzQ8LS4+OuwIHTvvZY06yqEoOloQ7zuAT4Y77OCrOZooojq9Ais66hWOO0L5Jjry7r86VcuWOvyadTuG7ik78LFGOxX8rzqoMvs5R9CpOo1vqjsWHdM6RptbOsJVEjrTCkA7SjNbOjgltjrloiE7LuExOooyITzs4Ks5joApOkGqgTqbbbk7joApOsUwxzog\u002fL48rhcZPNyPpTwEtIs6cOO6OdY2FDot8oU6OMwFO++XpDuo2Yo8\\u002fLuvzoWfQQ7q1x6OYhyzTpfHE48VeSMOskYIzyXSMA65bCTOk2vSTovG707kF9OOrFL9jmSyfA7XkBFOUPvDjpgVJI68P9FOvJBJTutsGQ7\u002fMKXOznrHTxF6LU6rkpOOjMItjsGYaE87OCrOaJjCTxA5Xc6ozntOTUqzTrsxTg68u6\u002fOtCzkDvs4Ks57OCrOU\u002f5DDvQur85joApOjWhWTs7myA6aHh6OiYgOToW5547hZIjOh\u002fH4Ttw0QM85bCTOl4WyjqENwo6++SAOrxcQDq9s+Q6yV6IOj74kDrs4Ks5xyArObZ6bzqrHNM7ZPTJOrScaDuzlhg9xufBOwhFAjpEkfw69N4kPOzgqzmlr8Y71jYUOvdVbjrs4Ks5jl3OOpLRfzr3VW46Xj3+O2dg\u002fjpw47o5OCW2On1mdDm+3Vw7y7YtOnAP1zlxewY8Oi3fOlhmVzqEWC87cOO6OXDjujns4Ks5Ams1OYPEUzulwM06GLGhOiqEOzpw47o5fF9sO+zgqzns4Ks5XidmOiqEOzo3dKQ7SdCJOf\u002fEETt4lFY6++SAOpDdCzrD6vM6ktF\u002fOqjQbjpw47o5F9+NOnsKlTqah486NtUfOmPv0TpR5gI8tI\u002ffOjQkHDryceg5cOO6OQWVHDxIMCE6W9m6Om0eEzww5Zk67OCrOd35BDrbTo87hZIjOj+rajpaLwU7QNfgOvRRIzseOxA87fmkO3ZXnjurHNM7wxfbO+iSkDr5z3E71bnkOmwe\u002fzmOgCk6ozoaO3kVCjvloiE7eAi\u002fOvuz8zmSZeo6joApOovVWTqjkGc6wKOfOsPBIzoUDNE5riT+PIWSIzohwzg6KoQ7OjZnujpcjbI5RTcDPJyfxjpw47o5hZIjOjQ3dTvs4Ks5Aj0EOo5WUDssxBc8moePOg9w1zkWpdc6ETi4OxZowznhmYg6PXsiOu8UPDw4TaE7bUEgOuI+\u002fjncSe85kN0LOgvsbjkNyy07kpXnPKmlBD2x9wA6AIehOk39Szrs4Ks5LsJEOkL5JjpFE2U6ZewlO2ZMITsVBgM9k7HwOyxpbjvLti06tHwLPIWmRTvWJNo5joApOo6AKTrgBEM6KZxuOrWsHjuzoq07joApOgJrNTky2To7cN4EOh0mKTvy7r86dPo7O54adTs="},"xaxis":"x","yaxis":"y","type":"histogram"},{"hovertemplate":"feature=proba__RARE_\u003cbr\u003evalue=%{x}\u003cextra\u003 ...
